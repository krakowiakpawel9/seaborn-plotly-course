# %% [markdown]
# <a href="https://colab.research.google.com/github/krakowiakpawel9/plotly-course/blob/master/plotly-tut/06_maps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q chart_studio
# !pip install -q --upgrade plotly

# %%
import pandas as pd
df = pd.read_csv("https://ml-repository-krakers.s3-eu-west-1.amazonaws.com/plotly-course/us-cities-top-1k.csv")
df.head()
# Out:
#          City           State  Population        lat         lon
# 0  Marysville      Washington       63269  48.051764 -122.177082
# 1      Perris      California       72326  33.782519 -117.228648
# 2   Cleveland            Ohio      390113  41.499320  -81.694361
# 3   Worcester   Massachusetts      182544  42.262593  -71.802293
# 4    Columbia  South Carolina      133358  34.000710  -81.034814

# %%
import plotly.express as px

def plot_map(mapbox_style):
    fig = px.scatter_mapbox(df, lat='lat', lon='lon',
                           hover_name='City', hover_data=['State', 'Population'], zoom=3)
    fig.update_layout(mapbox_style=mapbox_style,
                     margin={'r': 10, 't': 10, 'l': 10, 'b': 10})
    fig.show()

# %%
plot_map('carto-positron')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="008d7fa5-7ca3-4413-bf82-5cd412a7d38e" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("008d7fa5-7ca3-4413-bf82-5cd412a7d38e")) {
#                     Plotly.newPlot(
#                         '008d7fa5-7ca3-4413-bf82-5cd412a7d38e',
# ...

# %%
plot_map('carto-darkmatter')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8d54ce9d-a4de-46cd-890a-dee592a1d3ae" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8d54ce9d-a4de-46cd-890a-dee592a1d3ae")) {
#                     Plotly.newPlot(
#                         '8d54ce9d-a4de-46cd-890a-dee592a1d3ae',
# ...

# %%
plot_map('stamen-terrain')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c2825c7a-7b93-4901-a8d8-c5d920a4d260" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c2825c7a-7b93-4901-a8d8-c5d920a4d260")) {
#                     Plotly.newPlot(
#                         'c2825c7a-7b93-4901-a8d8-c5d920a4d260',
# ...

# %%
plot_map('stamen-toner')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b3b1bbde-5595-4c32-a451-25dcb4910636" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b3b1bbde-5595-4c32-a451-25dcb4910636")) {
#                     Plotly.newPlot(
#                         'b3b1bbde-5595-4c32-a451-25dcb4910636',
# ...

# %%
px.set_mapbox_access_token('pk.eyJ1Ijoia3Jha293aWFrcGF3ZWw5IiwiYSI6ImNqenYyNTA2czAzcHEzZHE5cXJndjg3ODQifQ.u-yCdqx88HBjogcmrknwRA')

# %%
plot_map('basic')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c5634243-5dc6-4de5-81e8-6dcbcea7b2bc" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c5634243-5dc6-4de5-81e8-6dcbcea7b2bc")) {
#                     Plotly.newPlot(
#                         'c5634243-5dc6-4de5-81e8-6dcbcea7b2bc',
# ...

# %%
plot_map('streets')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="20762fff-7b99-4897-b257-58afe52ce541" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("20762fff-7b99-4897-b257-58afe52ce541")) {
#                     Plotly.newPlot(
#                         '20762fff-7b99-4897-b257-58afe52ce541',
# ...

# %%
plot_map('satellite')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ff9eefcd-8453-4e77-bf2b-bf8bce3cce8e" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ff9eefcd-8453-4e77-bf2b-bf8bce3cce8e")) {
#                     Plotly.newPlot(
#                         'ff9eefcd-8453-4e77-bf2b-bf8bce3cce8e',
# ...

# %%
df = px.data.gapminder()
df.head()
# Out:
#        country continent  year  ...   gdpPercap  iso_alpha  iso_num
# 0  Afghanistan      Asia  1952  ...  779.445314        AFG        4
# 1  Afghanistan      Asia  1957  ...  820.853030        AFG        4
# 2  Afghanistan      Asia  1962  ...  853.100710        AFG        4
# 3  Afghanistan      Asia  1967  ...  836.197138        AFG        4
# 4  Afghanistan      Asia  1972  ...  739.981106        AFG        4
#
# [5 rows x 8 columns]

# %%
df_2007 = df[df.year == 2007]
df_2007.describe()
# Out:
#          year     lifeExp           pop     gdpPercap     iso_num
# count   142.0  142.000000  1.420000e+02    142.000000  142.000000
# mean   2007.0   67.007423  4.402122e+07  11680.071820  425.880282
# std       0.0   12.073021  1.476214e+08  12859.937337  249.111541
# min    2007.0   39.613000  1.995790e+05    277.551859    4.000000
# 25%    2007.0   57.160250  4.508034e+06   1624.842248  209.500000
# 50%    2007.0   71.935500  1.051753e+07   6124.371109  410.000000
# 75%    2007.0   76.413250  3.121004e+07  18008.835640  636.000000
# max    2007.0   82.603000  1.318683e+09  49357.190170  894.000000

# %%
px.scatter_geo(df_2007, locations='iso_alpha', color='continent', hover_name='country',
              size='pop')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4a79a3b7-41a0-4de4-bcd7-12a8ca5afcc1" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4a79a3b7-41a0-4de4-bcd7-12a8ca5afcc1")) {
#                     Plotly.newPlot(
#                         '4a79a3b7-41a0-4de4-bcd7-12a8ca5afcc1',
# ...

# %%
px.scatter_geo(df_2007, locations='iso_alpha', color='continent', hover_name='country',
              size='pop', projection='natural earth')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d11d67d4-b2a8-4652-aad9-f88546dc21e2" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d11d67d4-b2a8-4652-aad9-f88546dc21e2")) {
#                     Plotly.newPlot(
#                         'd11d67d4-b2a8-4652-aad9-f88546dc21e2',
# ...

# %%
px.scatter_geo(df, locations='iso_alpha', color='continent', hover_name='country',
              size='pop', animation_frame='year', projection='natural earth')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f76423e1-6599-4033-b26e-9f84e12e7dac" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f76423e1-6599-4033-b26e-9f84e12e7dac")) {
#                     Plotly.newPlot(
#                         'f76423e1-6599-4033-b26e-9f84e12e7dac',
# ...

# %%
df = px.data.gapminder()
df.head()
# Out:
#        country continent  year  ...   gdpPercap  iso_alpha  iso_num
# 0  Afghanistan      Asia  1952  ...  779.445314        AFG        4
# 1  Afghanistan      Asia  1957  ...  820.853030        AFG        4
# 2  Afghanistan      Asia  1962  ...  853.100710        AFG        4
# 3  Afghanistan      Asia  1967  ...  836.197138        AFG        4
# 4  Afghanistan      Asia  1972  ...  739.981106        AFG        4
#
# [5 rows x 8 columns]

# %%
px.choropleth(df, locations='iso_alpha', color='lifeExp', hover_name='country')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c3e95347-3233-40fb-8c3b-fca60b024513" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c3e95347-3233-40fb-8c3b-fca60b024513")) {
#                     Plotly.newPlot(
#                         'c3e95347-3233-40fb-8c3b-fca60b024513',
# ...

# %%
raw = """AL / Albania
AD / Andorra
AM / Armenia
AT / Austria"
BY / Belarus
BE / Belgium
BA / Bosnia and Herzegovina
BG / Bulgaria
CH / Switzerland
CY / Cyprus
CZ / Czech Republic
DE / Germany
DK / Denmark
EE / Estonia
ES / Spain
FO / Faeroe Islands
FI / Finland
FR / France
GB / United Kingdom
GE / Georgia
GI / Gibraltar
GR / Greece
HU / Hungary
HR / Croatia
IE / Ireland
IS / Iceland
IT / Italy
LT / Lithuania
LU / Luxembourg
LV / Latvia
MC / Monaco
MK / Macedonia
MT / Malta
NO / Norway
NL / Netherlands
PO / Poland
PT / Portugal
RO / Romania
RU / Russian Federation
SE / Sweden
SI / Slovenia
SK / Slovakia (Slovakian Republic)
SM / San Marino
TR / Turkey
UA / Ukraine
VA / Vatican City State
"""

# %%
l = raw.split('\n')
l = [row.strip().split('/') for row in l][:-1]

code = []
country = []
for item in l:
    code.append(item[0].strip())
    country.append(item[1].strip())
    
print(code)
print(country)

df = pd.DataFrame(dict(code=code, country=country))
df = df.reset_index()
df.head()
# Out:
# ['AL', 'AD', 'AM', 'AT', 'BY', 'BE', 'BA', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'ES', 'FO', 'FI', 'FR', 'GB', 'GE', 'GI', 'GR', 'HU', 'HR', 'IE', 'IS', 'IT', 'LT', 'LU', 'LV', 'MC', 'MK', 'MT', 'NO', 'NL', 'PO', 'PT', 'RO', 'RU', 'SE', 'SI', 'SK', 'SM', 'TR', 'UA', 'VA']
# ['Albania', 'Andorra', 'Armenia', 'Austria', 'Belarus', 'Belgium', 'Bosnia and Herzegovina', 'Bulgaria', 'Switzerland', 'Cyprus', 'Czech Republic', 'Germany', 'Denmark', 'Estonia', 'Spain', 'Faeroe Islands', 'Finland', 'France', 'United Kingdom', 'Georgia', 'Gibraltar', 'Greece', 'Hungary', 'Croatia', 'Ireland', 'Iceland', 'Italy', 'Lithuania', 'Luxembourg', 'Latvia', 'Monaco', 'Macedonia', 'Malta', 'Norway', 'Netherlands', 'Poland', 'Portugal', 'Romania', 'Russian Federation', 'Sweden', 'Slovenia', 'Slovakia (Slovakian Republic)', 'San Marino', 'Turkey', 'Ukraine', 'Vatican City State']
#    index code  country
# 0      0   AL  Albania
# 1      1   AD  Andorra
# 2      2   AM  Armenia
# ...

# %%
px.choropleth(df, locations='country', color='index', locationmode='country names', hover_name='country')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="24ca01f3-80af-4cae-8541-3b532528540e" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("24ca01f3-80af-4cae-8541-3b532528540e")) {
#                     Plotly.newPlot(
#                         '24ca01f3-80af-4cae-8541-3b532528540e',
# ...

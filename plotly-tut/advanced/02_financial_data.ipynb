# %% [markdown]
# <a href="https://colab.research.google.com/github/krakowiakpawel9/seaborn-plotly-course/blob/master/plotly-tut/advanced/02_financial_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q chart_studio
# !pip install -q --upgrade plotly
# Out:
#      |████████████████████████████████| 81kB 5.3MB/s
#      |████████████████████████████████| 7.1MB 5.1MB/s

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetch stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df_amzn = fetch_financial_data(company='AMZN')
df_aapl = fetch_financial_data(company='AAPL')
df_msft = fetch_financial_data(company='MSFT')
df_nflx = fetch_financial_data(company='NFLX')
df_twtr = fetch_financial_data(company='TWTR')

# %%
df_amzn.head(2)
# Out:
#                Open     High      Low    Close     Volume
# Date
# 2019-08-30  1797.49  1799.74  1764.57  1776.29  3064147.0
# 2019-08-29  1783.00  1798.55  1777.25  1786.40  3018012.0

# %%
import pandas as pd

df = pd.concat([df_amzn.Close, df_aapl.Close, df_msft.Close, df_nflx.Close, df_twtr.Close], axis=1, join='inner')
df.columns = ['amazon', 'apple', 'microsoft', 'netflix', 'twitter']
df = df.reset_index()
df.head()
# Out:
#         Date   amazon   apple  microsoft  netflix  twitter
# 0 2019-08-30  1776.29  208.74     137.86   293.75    42.65
# 1 2019-08-29  1786.40  209.01     138.12   296.78    42.49
# 2 2019-08-28  1764.25  205.53     135.56   291.77    41.68
# 3 2019-08-27  1761.83  204.16     135.74   291.03    42.14
# 4 2019-08-26  1768.87  206.49     135.45   294.98    41.44

# %%
df.describe()
# Out:
#             amazon        apple    microsoft      netflix      twitter
# count  1463.000000  1463.000000  1463.000000  1463.000000  1463.000000
# mean    923.681869   130.936393    66.578410   167.575029    30.990014
# std     548.359541    42.583381    29.930979   111.739037    12.213158
# min     286.950000    64.442000    30.671000    44.887000    14.010000
# 25%     413.075000    98.405500    41.881500    79.964500    18.440000
# 50%     767.740000   116.860000    54.583000   120.810000    31.160000
# 75%    1469.630000   167.685000    91.037000   275.675000    38.735000
# max    2039.510000   228.520000   140.870000   418.970000    73.310000

# %%
import plotly.graph_objects as go

trace0 = go.Scatter(x=df.Date,
                   y=df.amazon,
                   name='Amazon')
trace1 = go.Scatter(x=df.Date,
                   y=df.apple,
                   name='Apple')
trace2 = go.Scatter(x=df.Date,
                   y=df.microsoft,
                   name='Microsoft')
trace3 = go.Scatter(x=df.Date,
                   y=df.netflix,
                   name='Netflix')
trace4 = go.Scatter(x=df.Date,
                   y=df.twitter,
                   name='Twitter')
data = [trace0, trace1, trace2, trace3, trace4]

layout = go.Layout(yaxis_type='log')

fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="268ec6f9-dcb9-4e69-8487-bd4378a3e2aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("268ec6f9-dcb9-4e69-8487-bd4378a3e2aa")) {
#                     Plotly.newPlot(
#                         '268ec6f9-dcb9-4e69-8487-bd4378a3e2aa',
# ...

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=df.Date,
    y=df.amazon,
    name='Amazon'
))

fig.add_trace(go.Scatter(
    x=df.Date,
    y=df.apple,
    name='Apple'
))

fig.update_layout(yaxis_type='log')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1435df75-5511-49d5-aa10-97f9ef05c4de" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1435df75-5511-49d5-aa10-97f9ef05c4de")) {
#                     Plotly.newPlot(
#                         '1435df75-5511-49d5-aa10-97f9ef05c4de',
# ...

# %%
data = [go.Scatter(x=df.Date, y=df[col], name=col) for col in df.columns[1:]]
layout = go.Layout(yaxis_type='log')

fig = go.Figure(data=data, layout=layout)
fig.write_html('price.html')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="037381d8-d0fc-4720-8689-4fbc35cdb98d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("037381d8-d0fc-4720-8689-4fbc35cdb98d")) {
#                     Plotly.newPlot(
#                         '037381d8-d0fc-4720-8689-4fbc35cdb98d',
# ...
